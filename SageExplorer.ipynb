# %%
from SageExplorer import *
S = StandardTableaux(15)
t= S.random_element()
w = SageExplorer(t)
# Out:
# HTML(value=u'<style></style>')
# <class 'sage.combinat.tableau.SemistandardTableau'>
# ...

# %%
w
# Out:
# SageExplorer(children=(HBox(children=(Label(value=u'Standard tableaux'), Textarea(value=u'  1  5  6 10\n  2  8  9 14\n  3 11 12\n  4 13 15\n  7'))), HBox(children=(Accordion(children=(Select(options=(('Object methods:', None), ('add_entry', <bound method StandardTableaux_all_with_category.element_class.add_entry of [[1, 5, 6, 10], [2, 8, 9, 14], [3, 11, 12], [4, 13, 15], [7]]>), ('anti_restrict', <bound method StandardTableaux_all_with_category.element_class.anti_restrict of [[1, 5, 6, 10], [2, 8, 9, 14], [3, 11, 12], [4, 13, 15], [7]]>), ('atom', <bound method StandardTableaux_all_with_category.element_class.atom of [[1, 5, 6, 10], [2, 8, 9, 14], [3, 11, 12], [4, 13, 15], [7]]>), ('bender_knuth_involution', <bound method StandardTableaux_all_with_category.element_class.bender_knuth_involution of [[1, 5, 6, 10], [2, 8, 9, 14], [3, 11, 12], [4, 13, 15], [7]]>), ('bump', <bound method StandardTableaux_all_with_category.element_class.bump of [[1, 5, 6, 10], [2, 8, 9, 14], [3, 11, 12], [
# ...
